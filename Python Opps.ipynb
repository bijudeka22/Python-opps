# %% [markdown]
# #Python Opps

# %% [markdown]
# #1.What is Object-Oriented Programming (OOP)?
# - Object-oriented programming (OOP) is a programming paradigm based on the concept of "objects", which can contain data, in the form of fields (often known as attributes), and code, in the form of procedures (often known as methods). A feature of objects is that an object's procedures can access and often modify the data fields of the object with which they are associated (objects have a notion of "this" or "self"). Thus in OOP, computer programs are designed by making them out of objects that interact with one another. OOP languages are diverse, but the most popular ones are class-based, meaning that objects are instances of classes, which also determine their types.

# %% [markdown]
# #2.What is a class in OOP?
# - In object-oriented programming (OOP), a class is a blueprint or template for creating objects.  It defines the structure and behavior that objects of that class will share.
# A class is a user-defined data type that encapsulates data (attributes) and the functions that operate on that data (methods) into a single unit.  Objects are instances of a class.

# %% [markdown]
# #3.What is an object in OOP?
# - In object-oriented programming (OOP), an object is a specific instance of a class.  It's a concrete realization of the blueprint defined by the class.
#
# An object is a runtime instance of a class. It's a self-contained entity that has both data (attributes) and behavior (methods) defined by its class.  Each object has its own unique set of data values, but they all share the same methods defined by their class.

# %% [markdown]
# #4.What is the difference between abstraction and encapsulation?
#
#  * Abstraction is about hiding complexity and showing only what's necessary.
#  * Encapsulation is about bundling data and methods and controlling access to the data.
# Abstraction and encapsulation often work together. Abstraction helps to define the interface of an object, while encapsulation helps to protect the internal state of the object and ensure that it behaves correctly.

# %% [markdown]
# #5.What are dunder methods in Python?
# - Dunder methods, also known as magic methods or special methods, are a set of methods in Python that allow you to customize how your objects behave.  They are called "dunder" methods because they have double underscores (double underscores) at the beginning and end of their names (e.g., __init__, __str__, __len__).
# These methods are not typically called directly by your code. Instead, they are invoked automatically by Python when you use certain operators or functions on your objects.  They enable operator overloading, allowing you to define how standard operators like +, -, *, ==, etc., work with your custom objects.

# %% [markdown]
# #6.Explain the concept of inheritance in OOP?
# - Inheritance is a fundamental concept in object-oriented programming (OOP) that allows you to create new classes (called derived classes or subclasses) based on existing classes (called base classes or superclasses).  Think of it like a parent-child relationship: the child (derived class) inherits characteristics and behaviors from the parent (base class) but can also have its own unique traits.

# %% [markdown]
# #7.What is polymorphism in OOP?
# - In object-oriented programming (OOP), polymorphism is a fundamental concept that refers to the ability of objects of different classes to respond to the same method call in their own specific ways. In simpler terms, it allows you to treat objects of different types as if they were objects of a common type.
# Here's a breakdown of polymorphism:
#  * "Poly" means "many," and "morph" means "form." So, polymorphism literally means "many forms."
#
# Polymorphism is a powerful concept in OOP that allows you to write more flexible, reusable, and maintainable code. It enables you to treat objects of different classes in a uniform way, making your code more adaptable to changes and extensions.

# %% [markdown]
# #8.How is encapsulation achieved in Python?
# - Encapsulation is one of the four fundamental principles of object-oriented programming (OOP). It involves bundling data (attributes) and methods (functions) that operate on that data into a single unit, called a class. Encapsulation also controls access to the data, preventing direct modification from outside the class.

# %% [markdown]
# #9. What is a constructor in Python?
# - In Python, a constructor is a special method within a class that is automatically called when you create a new object (instance) of that class.  Its primary purpose is to initialize the object's attributes (data) and set it up for use.  You define a constructor using the name __init__ (double underscores on either side).
#
#
#  * Every class can have at most one constructor (__init__).
#  * If you don't define a constructor, Python provides a default constructor that does nothing.
#  * Constructors are essential for properly initializing objects and setting them up for use. They ensure that objects are in a valid state when they are created.

# %% [markdown]
# #10.What are class and static methods in Python?
# - Both class methods and static methods are special types of methods in Python that are bound to the class and not the instance of the class. However, they have some key differences in how they are defined and used.
#
#  Class Methods
#  * Definition: A class method is defined using the @classmethod decorator.
#  * First Argument: The first argument of a class method is always cls, which is a reference to the class itself.
#  * Access to Class State: Class methods have access to the state of the class (class attributes) and can modify it.
#  * Usage: Class methods are typically used to create factory methods (methods that return instances of the class), to access or modify class-level variables, or for operations that are related to the class as a whole.
#
# Static Methods
#  * Definition: A static method is defined using the @staticmethod decorator.
#  * No Implicit Argument: Static methods do not have any implicit first argument (like self or cls).
#  * No Access to Class or Instance State: Static methods do not have access to the state of the class or the instance.
#  * Usage: Static methods are essentially regular functions that are part of the class. They are used for utility functions that don't depend on the class or instance state.
#
# In essence, class methods are used for operations that involve the class, while static methods are used for operations that are related to the class but don't require access to its internal state.

# %% [markdown]
# #11.What is method overloading in Python?
#
#  * Python's Approach: Python's dynamic typing and how it handles function definitions mean that if you define two methods with the same name in a class, the second definition simply overwrites the first. Python doesn't allow you to have two separate methods with the same name coexisting in the same scope.
# How Python Achieves Similar Results:
# While true method overloading isn't there, Python offers ways to achieve similar flexibility:
#  * Default Arguments: You can use default arguments to create a method that can be called with a varying number of arguments.
#  * Variable Length Arguments (*args and **kwargs): These allow you to handle an arbitrary number of positional or keyword arguments.
#  * Type Checking (Within the Method): You can perform type checking within the method to handle different types of input.
# In essence: Python doesn't have method overloading in the traditional sense. However, you can use default arguments, variable-length arguments (*args, **kwargs), and conditional logic within a method to achieve similar flexibility and handle different input scenarios.

# %% [markdown]
# #12.What is method overriding in OOP?
#
# - Method overriding is a key concept in object-oriented programming (OOP) that allows a subclass (or derived class) to provide a specific implementation for a method that is already defined in its superclass (or base class).
#
#
#  * Method overriding occurs when a subclass provides a different implementation for a method that is already defined in its superclass.
#  * The overriding method must have the same name, parameters, and return type as the overridden method.
#  * Method overriding is a key aspect of polymorphism in OOP.

# %% [markdown]
# #13.What is a property decorator in Python?
#
# - In Python, a property decorator (@property) is a way to define a method that is accessed like an attribute. It allows you to create "managed attributes" or "computed properties" that provide controlled access to data and can perform calculations or other operations behind the scenes when the attribute is accessed or modified.

# %% [markdown]
# #14. Why is polymorphism important in OOP?
# - Polymorphism is a crucial concept in object-oriented programming (OOP) for several compelling reasons.
# Polymorphism is a powerful tool that makes your code more flexible, reusable, maintainable, and easier to extend. It allows you to write code that is more abstract and less dependent on specific types, which leads to more robust and adaptable software.  It's a cornerstone of good object-oriented design.

# %% [markdown]
# #15.What is an abstract class in Python?
#
# - In Python, an abstract class is a class that cannot be instantiated directly.  Its primary purpose is to serve as a blueprint or template for other classes (its subclasses).  Abstract classes define a common interface and sometimes provide default implementations for some methods, but they often leave some methods as abstract, requiring subclasses to provide concrete implementations.

# %% [markdown]
# #16.What are the advantages of OOP?
#
# - Object-oriented programming (OOP) offers numerous advantages that have made it a dominant paradigm in software development. Here's a breakdown of the key benefits:
# 1. Modularity:
#  * Breaking Down Complexity: OOP encourages breaking down complex problems into smaller, manageable units called objects. Each object represents a specific entity or concept, making the overall system easier to understand and design.
#  * Independent Components: Objects are relatively independent of each other.  Changes to one object are less likely to affect other parts of the system, reducing the risk of unintended side effects.
# 2. Reusability:
#  * Inheritance: OOP allows you to create new classes (subclasses) that inherit properties and behaviors from existing classes (superclasses). This promotes code reuse, as you don't have to rewrite code for similar objects.  You can extend and specialize existing classes instead.
#  * Component-Based Development: Objects can be treated as reusable components.  Once an object is created, it can be used in different parts of the program or even in other programs, saving development time and effort.
# 3. Maintainability:
#  * Easier Modifications: Because objects are self-contained, changes to one object are less likely to affect other objects. This makes it easier to modify and update the code without introducing bugs in unrelated parts of the system.
#  * Simplified Debugging:  When a problem occurs, it's often easier to isolate the faulty object and debug it, as the problem is more likely to be localized.
#  * Improved Readability: Well-structured OOP code is often easier to read and understand because it models real-world entities and their interactions in a more intuitive way.
# 4. Extensibility:
#  * Adding New Features: OOP makes it easy to add new features to a system. You can create new classes that inherit from existing ones or create entirely new objects without affecting the existing code.
#  * Open/Closed Principle: OOP supports the open/closed principle, which states that software entities (classes, modules, functions, etc.) should be open for extension, but closed for modification. This means you can add new functionality without changing existing code, reducing the risk of introducing bugs.
# 5. Abstraction:
#  * Hiding Complexity: OOP allows you to hide the complex implementation details of an object and expose only a simple interface for interacting with it.  This simplifies the use of objects and makes the code easier to understand.
#  * Focus on Behavior: Abstraction lets you focus on what an object does rather than how it does it.
# 6. Encapsulation:
#  * Data Hiding: Encapsulation protects the internal state of an object by preventing direct access from outside the object.  Access to the object's data is controlled through methods (getters and setters), allowing you to validate data and ensure consistency.
#  * Data Integrity: Encapsulation helps maintain data integrity by preventing accidental or unauthorized modification of an object's state.
# 7. Polymorphism:
#  * Flexibility: Polymorphism allows objects of different classes to be treated in a uniform way through their common interface (e.g., a common superclass).  This makes your code more flexible and reusable.
#  * Generic Code: You can write code that works with objects of different classes without needing to know their specific type, as long as they adhere to the common interface.
# 8. Real-World Modeling:
#  * Intuitive Design: OOP allows you to model real-world entities and their interactions in a more natural and intuitive way. This makes the design process easier and the resulting code more understandable.
# 9. Improved Software Development Process:
#  * Faster Development: The reusability and modularity of OOP can lead to faster development times.
#  * Reduced Development Costs:  Code reuse and easier maintenance can reduce development costs.
#  * Improved Software Quality:  The structured approach and the emphasis on data integrity and encapsulation can lead to higher-quality software.

# %% [markdown]
# #17. What is the difference between a class variable and an instance variable?
#
# - Class variables and instance variables are both used to store data within a class in object-oriented programming (OOP), but they have some key differences in terms of their scope, usage, and how they are accessed.
#
# * Class variables are declared within the class but outside of any method. They belong to the class itself and are shared among all instances (objects) of that class. There is only one copy of a class variable, regardless of how many objects are created.
#
# * Instance variables are declared inside methods, specifically within the __init__ method (the constructor) or other methods of the class. They belong to the individual instances (objects) of the class. Each instance has its own separate copy of the instance variables.
#
# * Class variables are for data that is common to all instances of a class.
# * Instance variables are for data that is unique to each instance of a class.

# %% [markdown]
# #18.What is multiple inheritance in Python?
#
# - Multiple inheritance is a feature in object-oriented programming where a class can inherit from multiple parent classes (also known as base classes or superclasses). This means the child class (or derived class) inherits attributes and methods from all its parent classes.  It allows you to combine functionalities from different classes into a single class.
# - Multiple inheritance is a powerful feature, but it should be used carefully to avoid introducing unnecessary complexity and potential problems.

# %% [markdown]
# #19.Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python ?
#
# - Both __str__ and __repr__ are special methods (also known as "dunder methods" or "magic methods") in Python that are used to represent objects as strings. However, they serve slightly different purposes and are used in different contexts.
# __str__(self)
#  * Purpose: The primary purpose of __str__ is to provide a human-readable, informal string representation of an object.  It's meant to be easily understood by users.
#  * Usage:  __str__ is called when you use the str() function on an object or when you print() an object.  It's also used implicitly when you use an object in a string context (e.g., string formatting).
#
#
# __repr__(self)
#  * Purpose: The primary purpose of __repr__ is to provide an unambiguous, developer-oriented string representation of an object. It should ideally contain enough information to recreate the object.  It's meant to be used for debugging and development.
#  * Usage: __repr__ is called when you use the repr() function on an object or when you inspect an object in an interactive interpreter (like the Python REPL).  If __str__ is not defined, __repr__ is also used as the string representation in print() and str().
#  __str__ is for users, and __repr__ is for developers.  Defining both methods provides flexibility in how your objects are represented as strings in different contexts.

# %% [markdown]
# #.20.What is the significance of the ‘super()’ function in Python?
#
# -In Python, the super() function is a built-in function that is used to call methods from a parent (or super) class in a child (or derived) class. It plays a crucial role in inheritance and method resolution order (MRO) in object-oriented programming.
#
# The super() function is a powerful tool in Python's object-oriented programming. It provides a clean and reliable way to access parent class methods, maintain the correct method resolution order, promote code reusability, and support dynamic dispatch. Understanding and using super() effectively is essential for writing robust and maintainable object-oriented code in Python.

# %% [markdown]
# #21.What is the significance of the __del__ method in Python?
#
# -The __del__ method (also known as the destructor or finalizer) in Python is a special method that is automatically called when an object's reference count drops to zero, meaning it's about to be garbage collected.
# The original intent behind __del__ was to allow objects to perform cleanup operations (like closing files, releasing resources, or flushing buffers) before they are destroyed.

# %% [markdown]
# #22.What is the difference between @staticmethod and @classmethod in Python.?
#
# - * Use @staticmethod when you have a function that is related to the class but doesn't need to access or modify the class or instance state.  It's primarily for organization and grouping related functions.
#  * Use @classmethod when you need to work with the class itself, such as creating factory methods or modifying class-level attributes.  Class methods are tightly coupled to the class and can interact with its state.

# %% [markdown]
# #23.How does polymorphism work in Python with inheritance?
#
# - Polymorphism, combined with inheritance, is a powerful concept in Python (and OOP in general) that allows you to treat objects of different classes in a uniform way through a common interface (usually a base class or abstract class).
# - * Inheritance: You have a base class (superclass) that defines a set of methods (the interface).  Then, you have one or more derived classes (subclasses) that inherit from the base class.
#  * Method Overriding: Each derived class can override (redefine) the methods inherited from the base class to provide its own specific implementation.  This is where the "many forms" (poly-morphism) aspect comes in.  Each subclass can implement the method in a way that's appropriate for its type.
#  * Polymorphic Calls: You can then write code that works with objects of the base class.  Because of polymorphism, this code will also work correctly with objects of any of the derived classes. When you call a method on an object, Python's runtime system dynamically determines the actual type of the object and calls the appropriate version of the method (either the one in the base class or the overridden one in the derived class).

# %% [markdown]
# #24.What is method chaining in Python OOP?
# - Method chaining in Python is a technique where you can call multiple methods on the same object in a single line of code, one after the other.  Each method call returns the object itself (or another object that supports chaining), allowing you to chain the next method call directly.  It makes the code more concise and readable, especially when performing a series of operations on an object.
# How Method Chaining Works
# Method chaining relies on the fact that most methods in a class return self (a reference to the current object) after they have performed their operation.  This allows you to call another method immediately on the returned object.

# %% [markdown]
# #25.What is the purpose of the __call__ method in Python?
#
# -The __call__ method in Python allows you to make instances of a class callable, just like regular functions.
# - the __call__ method is a powerful tool for creating callable objects in Python, enhancing code readability, flexibility, and expressiveness.

# %% [markdown]
# #Practicle

# %%
#1.Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".
class Animal:
    def speak(self):
        print("Generic animal sound")

class Dog(Animal):
    def speak(self):
        print("Bark!")


my_dog = Dog()
my_dog.speak()
# Out:
# Bark!

# %%
#2.Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.?


from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14159 * self.radius * self.radius

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

# Create instances of Circle and Rectangle
circle = Circle(5)
rectangle = Rectangle(4, 6)

# Calculate and print the areas
print("Area of Circle:", circle.area())
print("Area of Rectangle:", rectangle.area())
# Out:
# Area of Circle: 78.53975
# Area of Rectangle: 24

# %%
#3.Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.


class Vehicle:
    def __init__(self, type):
        self.type = type

    def display_type(self):
        print(f"Vehicle Type: {self.type}")

class Car(Vehicle):
    def __init__(self, type, model, num_doors):
        super().__init__(type)  # Call the parent class's __init__
        self.model = model
        self.num_doors = num_doors

    def display_car_details(self):
        print(f"Model: {self.model}")
        print(f"Number of Doors: {self.num_doors}")


class ElectricCar(Car):
    def __init__(self, type, model, num_doors, battery_capacity):
        super().__init__(type, model, num_doors) # Call the Car class's __init__
        self.battery_capacity = battery_capacity

    def display_electric_details(self):
        print(f"Battery Capacity: {self.battery_capacity} kWh")


# Create instances of each class
vehicle = Vehicle("Generic")
car = Car("Car", "Sedan", 4)
electric_car = ElectricCar("Electric", "Tesla Model 3", 4, 75)

# Demonstrate the inheritance
vehicle.display_type()  # Output: Vehicle Type: Generic

car.display_type()       # Output: Vehicle Type: Car
car.display_car_details() # Output: Model: Sedan, Number of Doors: 4

electric_car.display_type()        # Output: Vehicle Type: Electric
electric_car.display_car_details()  # Output: Model: Tesla Model 3, Number of Doors: 4
electric_car.display_electric_details() # Output: Battery Capacity: 75 kWh

# Illustrate accessing attributes from different levels
print(electric_car.type)  # Output: Electric (from Vehicle)
print(electric_car.model) # Output: Tesla Model 3 (from Car)
print(electric_car.battery_capacity) # Output: 75 (from ElectricCar)
# Out:
# Vehicle Type: Generic
# Vehicle Type: Car
# Model: Sedan
# Number of Doors: 4
# Vehicle Type: Electric
# Model: Tesla Model 3
# Number of Doors: 4
# Battery Capacity: 75 kWh
# Electric
# Tesla Model 3
# 75

# %%
#4.Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.


class Vehicle:
    def __init__(self, type):
        self.type = type

    def display_type(self):
        print(f"Vehicle Type: {self.type}")

class Car(Vehicle):
    def __init__(self, type, model, num_doors):
        super().__init__(type)  # Call the parent class's __init__
        self.model = model
        self.num_doors = num_doors

    def display_car_details(self):
        print(f"Model: {self.model}")
        print(f"Number of Doors: {self.num_doors}")


class ElectricCar(Car):
    def __init__(self, type, model, num_doors, battery_capacity):
        super().__init__(type, model, num_doors) # Call the Car class's __init__
        self.battery_capacity = battery_capacity

    def display_electric_details(self):
        print(f"Battery Capacity: {self.battery_capacity} kWh")


vehicle = Vehicle("Generic")
car = Car("Car", "Sedan", 4)
electric_car = ElectricCar("Electric", "Tesla Model 3", 4, 75)

vehicle.display_type()

car.display_type()
car.display_car_details()

electric_car.display_type()
electric_car.display_car_details()
electric_car.display_electric_details()

# Illustrate accessing attributes from different levels
print(electric_car.type)
print(electric_car.model)
print(electric_car.battery_capacity)
# Out:
# Vehicle Type: Generic
# Vehicle Type: Car
# Model: Sedan
# Number of Doors: 4
# Vehicle Type: Electric
# Model: Tesla Model 3
# Number of Doors: 4
# Battery Capacity: 75 kWh
# Electric
# Tesla Model 3
# 75

# %%
#5.Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.


class BankAccount:
    def __init__(self, initial_balance=0):
        """
        Initializes a BankAccount object with an optional initial balance.

        Args:
            initial_balance (float, optional): The initial balance of the account. Defaults to 0.
        """
        self.__balance = initial_balance  # Encapsulate balance as a private attribute

    def deposit(self, amount):
        """
        Deposits the specified amount into the account.

        Args:
            amount (float): The amount to deposit.
        """
        if amount > 0:
            self.__balance += amount
            print(f"Deposited ${amount:.2f}. New balance: ${self.__balance:.2f}")
        else:
            print("Invalid deposit amount. Amount must be greater than 0.")

    def withdraw(self, amount):
        """
        Withdraws the specified amount from the account.

        Args:
            amount (float): The amount to withdraw.
        """
        if amount > 0 and amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew ${amount:.2f}. New balance: ${self.__balance:.2f}")
        elif amount <= 0:
            print("Invalid withdrawal amount. Amount must be greater than 0.")
        else:
            print("Insufficient funds.")

    def check_balance(self):
        """
        Returns the current balance of the account.

        Returns:
            float: The current balance of the account.
        """
        print(f"Current balance: ${self.__balance:.2f}")


# Create a BankAccount object
account = BankAccount(1000)

# Test deposit
account.deposit(500)

# Test withdrawal
account.withdraw(200)

# Test check balance
account.check_balance()
# Out:
# Deposited $500.00. New balance: $1500.00
# Withdrew $200.00. New balance: $1300.00
# Current balance: $1300.00

# %%
#6.Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().?

class Instrument:
    def play(self):
        print("Playing an instrument...")  # Default behavior

class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar...")

class Piano(Instrument):
    def play(self):
        print("Tickling the ivories...")

# Demonstrate polymorphism
instruments = [Guitar(), Piano()]

for instrument in instruments:
    instrument.play()  # Calls the appropriate play() method at runtime
# Out:
# Strumming the guitar...
# Tickling the ivories...

# %%
#7.Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.?
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        """Adds two numbers.

        Args:
            a: The first number.
            b: The second number.

        Returns:
            The sum of a and b.
        """
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        """Subtracts two numbers.

        Args:
            a: The first number.
            b: The second number.

        Returns:
            The difference of a and b.
        """
        return a - b

# Demonstrate usage
result_add = MathOperations.add_numbers(5, 3)
result_subtract = MathOperations.subtract_numbers(10, 4)

print(f"Addition result: {result_add}")
print(f"Subtraction result: {result_subtract}")
# Out:
# Addition result: 8
# Subtraction result: 6

# %%
#8.Implement a class Person with a class method to count the total number of persons created.

class Person:
    total_persons = 0

    def __init__(self, name):
        self.name = name
        Person.total_persons += 1

    @classmethod
    def get_total_persons(cls):
        return cls.total_persons


person1 = Person("Alice")
person2 = Person("Bob")
person3 = Person("Charlie")


total_persons = Person.get_total_persons()
print(f"Total number of persons created: {total_persons}")


print(f"Total number of persons created: {person1.get_total_persons()}")


print(Person.total_persons)
# Out:
# Total number of persons created: 3
# Total number of persons created: 3
# 3

# %%
#9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".

class Fraction:
    def __init__(self, numerator, denominator):
        if denominator == 0:
            raise ZeroDivisionError("Denominator cannot be zero.")
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"


    def __repr__(self):
        return f"Fraction({self.numerator}, {self.denominator})"

    def simplify(self):
        import math
        common_divisor = math.gcd(self.numerator, self.denominator)
        return Fraction(self.numerator // common_divisor, self.denominator // common_divisor)


fraction1 = Fraction(3, 4)
print(fraction1)
fraction2 = Fraction(1, 2)
print(fraction2)

fraction3 = Fraction(6, 8)
print(fraction3)
print(fraction3.simplify())
# Out:
# 3/4
# 1/2
# 6/8
# 3/4

# %%
#10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.

class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        if isinstance(other, Vector):  # Check if the other operand is also a Vector
            return Vector(self.x + other.x, self.y + other.y)
        else:
            raise TypeError("Can only add another Vector object.")

    def __str__(self):  # For easy printing
        return f"({self.x}, {self.y})"


v1 = Vector(2, 3)
v2 = Vector(1, -1)


result_vector = v1 + v2


print(f"Result: {result_vector}")
# Out:
# Result: (3, 2)

# %%
#11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Create a Person object
person = Person("BIJU", 32)

# Call the greet() method
person.greet()
# Out:
# Hello, my name is BIJU and I am 32 years old.

# %%
#12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.?
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        if not self.grades:
            return 0  # Return 0 if the list is empty
        return sum(self.grades) / len(self.grades)

# Example usage
student1 = Student("BIJU", [85, 92, 78, 90])
average1 = student1.average_grade()
print(f"{student1.name}'s average grade: {average1}")

student2 = Student("AJAY", [])
average2 = student2.average_grade()
print(f"{student2.name}'s average grade: {average2}")
# Out:
# BIJU's average grade: 86.25
# AJAY's average grade: 0

# %%
#13.. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.?

class Rectangle:
    def __init__(self):
        self.width = 0  # Initialize width to 0
        self.height = 0  # Initialize height to 0

    def set_dimensions(self, width, height):
        """Sets the width and height of the rectangle."""
        self.width = width
        self.height = height

    def area(self):
        """Calculates and returns the area of the rectangle."""
        return self.width * self.height


rectangle = Rectangle()

rectangle.set_dimensions(5, 10)

calculated_area = rectangle.area()

print(f"The area of the rectangle is: {calculated_area}")


rectangle2 = Rectangle()
rectangle2.set_dimensions(7,4)
print(f"The area of rectangle 2 is: {rectangle2.area()}")
# Out:
# The area of the rectangle is: 50
# The area of rectangle 2 is: 28

# %%
#14.Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.

class Employee:
    def __init__(self, name, hourly_rate):
        self.name = name
        self.hourly_rate = hourly_rate

    def calculate_salary(self, hours_worked):
        """Calculates the salary based on hours worked and hourly rate."""
        return hours_worked * self.hourly_rate

class Manager(Employee):
    def __init__(self, name, hourly_rate, bonus):
        super().__init__(name, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self, hours_worked):
        """Calculates the salary with the bonus."""
        base_salary = super().calculate_salary(hours_worked) # Call the parent class's calculate_salary
        return base_salary + self.bonus



employee = Employee("BIJU", 20)
employee_salary = employee.calculate_salary(40)
print(f"{employee.name}'s salary: ${employee_salary}")

manager = Manager("RAHUL", 30, 500)
manager_salary = manager.calculate_salary(40)
print(f"{manager.name}'s salary: ${manager_salary}")


manager2 = Manager("AJAY", 40, 1000)
print(f"{manager2.name}'s salary: ${manager2.calculate_salary(50)}")
# Out:
# BIJU's salary: $800
# RAHUL's salary: $1700
# AJAY's salary: $3000

# %%
#15.Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.

class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

product1 = Product("Laptop", 1200, 2)
total1 = product1.total_price()
print(f"Total price of {product1.quantity} {product1.name}(s): ${total1}")
product2 = Product("Mouse", 25, 5)
total2 = product2.total_price()
print(f"Total price of {product2.quantity} {product2.name}(s): ${total2}")
# Out:
# Total price of 2 Laptop(s): $2400
# Total price of 5 Mouse(s): $125

# %%
#16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.?

from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        print("Moo")

class Sheep(Animal):
    def sound(self):
        print("Baa")


cow = Cow()
sheep = Sheep()


cow.sound()
sheep.sound()
# Out:
# Moo
# Baa

# %%
#17.Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.

class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"Title: {self.title}, Author: {self.author}, Year Published: {self.year_published}"


book = Book("The Lord of the Rings", "J.R.R. Tolkien", 1954)
book_info = book.get_book_info()
print(book_info)
# Out:
# Title: The Lord of the Rings, Author: J.R.R. Tolkien, Year Published: 1954

# %%
#18.Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.

class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

    def __str__(self):
        return f"Address: {self.address}, Price: ${self.price}"


class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

    def __str__(self): # Overriding the __str__ method for Mansion
        return f"{super().__str__()}, Number of Rooms: {self.number_of_rooms}"



house = House("123 Main St", 250000)
print(house)

mansion = Mansion("456 Oak Ave", 1000000, 10)
print(mansion)


mansion2 = Mansion("789 Pine Ln", 1500000, 15)
print(mansion2)
# Out:
# Address: 123 Main St, Price: $250000
# Address: 456 Oak Ave, Price: $1000000, Number of Rooms: 10
# Address: 789 Pine Ln, Price: $1500000, Number of Rooms: 15
